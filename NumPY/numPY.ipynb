# %%
import numpy as np

# %%
a = np.array([1,2,3], dtype='int16')
print(a)
# Out:
# [1 2 3]

# %%
b= np.array([[9,8,7],[1,2,3]])
print(b)
# Out:
# [[9 8 7]
#  [1 2 3]]

# %%
#Get dimension
a.ndim
# Out:
# 1

# %%
# Get Shape
b.shape
# Out:
# (2, 3)

# %%
# Get Type
a.dtype
# Out:
# dtype('int16')

# %%
# Get size
a.itemsize
# Out:
# 2

# %%
#Get total size
a.size
# Out:
# 3
